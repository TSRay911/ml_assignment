# %%
import numpy as np
from environment import LifeStyleCoachEnv
from stable_baselines3 import TD3
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.noise import NormalActionNoise
import gymnasium as gym

env = LifeStyleCoachEnv()
check_env(env)  

noise_sigmas = [0.05, 0.1, 0.2]

for sigma in noise_sigmas:
    test_env = LifeStyleCoachEnv()
    n_actions = test_env.action_space.shape[-1]

    action_noise = NormalActionNoise(
        mean=np.zeros(n_actions),
        sigma=np.ones(n_actions) * sigma
    )

    model = TD3(
        "MultiInputPolicy",
        test_env,
        action_noise=action_noise,
        verbose=1,
        tensorboard_log=f"./tensorboard/sigma_{sigma:.2f}",
        learning_rate=1e-3,
        batch_size=256,
        gamma=0.99,
    )

    print(f"Test with {sigma}")
    model.learn(total_timesteps=250000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#
# Short test training with 0.05
# Logging to ./tensorboard/sigma_0.05/TD3_1
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 600       |
# |    ep_rew_mean     | -7.27e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 166       |
# |    time_elapsed    | 14        |
# |    total_timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 119       |
# |    critic_loss     | 326       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 600       |
# |    ep_rew_mean     | -7.42e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 168       |
# |    time_elapsed    | 28        |
# |    total_timesteps | 4800      |
# | train/             |           |
# |    actor_loss      | 200       |
# |    critic_loss     | 128       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 600       |
# |    ep_rew_mean     | -7.47e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 165       |
# |    time_elapsed    | 43        |
# |    total_timesteps | 7200      |
# | train/             |           |
# |    actor_loss      | 254       |
# |    critic_loss     | 1.42e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 600       |
# |    ep_rew_mean     | -7.49e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 166       |
# |    time_elapsed    | 57        |
# |    total_timesteps | 9600      |
# | train/             |           |
# |    actor_loss      | 314       |
# |    critic_loss     | 94.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9499      |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#
# Short test training with 0.1
# Logging to ./tensorboard/sigma_0.10/TD3_1
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 618       |
# |    ep_rew_mean     | -7.32e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 175       |
# |    time_elapsed    | 14        |
# |    total_timesteps | 2472      |
# | train/             |           |
# |    actor_loss      | 114       |
# |    critic_loss     | 13.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2371      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 609       |
# |    ep_rew_mean     | -7.44e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 175       |
# |    time_elapsed    | 27        |
# |    total_timesteps | 4872      |
# | train/             |           |
# |    actor_loss      | 191       |
# |    critic_loss     | 11.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4771      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 606       |
# |    ep_rew_mean     | -7.48e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 173       |
# |    time_elapsed    | 41        |
# |    total_timesteps | 7272      |
# | train/             |           |
# |    actor_loss      | 259       |
# |    critic_loss     | 795       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7171      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 604      |
# |    ep_rew_mean     | -7.5e+03 |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 172      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 9672     |
# | train/             |          |
# |    actor_loss      | 321      |
# |    critic_loss     | 1.29e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9571     |
# ---------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#
# Short test training with 0.2
# Logging to ./tensorboard/sigma_0.20/TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 618      |
# |    ep_rew_mean     | -7.5e+03 |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 169      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2472     |
# | train/             |          |
# |    actor_loss      | 96.4     |
# |    critic_loss     | 243      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2371     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 609       |
# |    ep_rew_mean     | -7.53e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 167       |
# |    time_elapsed    | 29        |
# |    total_timesteps | 4872      |
# | train/             |           |
# |    actor_loss      | 165       |
# |    critic_loss     | 55        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4771      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 606       |
# |    ep_rew_mean     | -7.54e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 164       |
# |    time_elapsed    | 44        |
# |    total_timesteps | 7272      |
# | train/             |           |
# |    actor_loss      | 237       |
# |    critic_loss     | 63.8      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7171      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 604       |
# |    ep_rew_mean     | -7.55e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 161       |
# |    time_elapsed    | 59        |
# |    total_timesteps | 9672      |
# | train/             |           |
# |    actor_loss      | 297       |
# |    critic_loss     | 960       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9571      |
# ----------------------------------
